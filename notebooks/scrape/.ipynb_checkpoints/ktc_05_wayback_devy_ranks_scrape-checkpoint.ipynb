# %% [markdown]
# # Imports

# %%
import re
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as BS
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from datetime import date, datetime, timedelta

# %% [markdown]
# # Create yesterday and today variables

# %%
yesterday = date.today()-timedelta(days=1)
today = date.today()

# %% [markdown]
# # Scrape current rankings

# %%
url = 'https://web.archive.org/web/20210302174949/https://keeptradecut.com/devy-rankings'
response = requests.get(url)
rankingsSoup = BS(response.content)

# Readable construction of dynasty-rankings dataframe

# values lists
rank_list = []
player_list = []
playerhref_list = []
positionrank_list = []
schoolabv_list = []
overalltier_list = []
value_list = []

# Relevant divs
playerlines = rankingsSoup.find_all('div', 'onePlayer')

for playerline in playerlines:
    
    # Grab current line's relevant player data
    rank = int(playerline.find('div', {'class':'rank-number'}).find('p').text)
    player = playerline.find('a').text
    playerhref = 'https://keeptradecut.com'+playerline.find('a')['href']
    positionrank = playerline.find('p', {'class':'position'}).text
    schoolabv = playerline.find('span', {'class' : 'player-team'}).text
    overalltier = playerline.find('div', 'player-info').find('p').text
    value = int(playerline.find('div', {'class':'value'}).find('p').text)
    
    # Append current line's data to value lists
    rank_list.append(rank)
    player_list.append(player)
    playerhref_list.append(playerhref)
    positionrank_list.append(positionrank)
    schoolabv_list.append(schoolabv)
    overalltier_list.append(overalltier)
    value_list.append(value)
    
# dict for df construction
rankings_dict = {
    'rank':rank_list,
    'player':player_list,
    'playerhref':playerhref_list,
    'positionrank':positionrank_list,
    'schoolabv':schoolabv_list,
    'overalltier':overalltier_list,
    'value':value_list
}

# Convert to DataFrame
wayback_devy_ranks = pd.DataFrame(rankings_dict)

# %% [markdown]
# # Add date column labelling today

# %%
wayback_devy_ranks['date'] = 'Mar. 2, 2021'

# %% [markdown]
# # Create historical values df, append new dynasty ranks and historical values to respective CSVs

# %%
wayback_devy_ranks['date'] = pd.to_datetime(wayback_devy_ranks['date'])
wayback_values = wayback_devy_ranks[['player', 'date', 'value']]

# wayback_devy_ranks.to_csv(f'../../data/ktc_historical_devy_ranks.csv', 
#                           mode = 'a', 
#                           index = False, 
#                           header = False
#                          )
# wayback_values.to_csv(f'../../data/ktc_historical_devy_values.csv', 
#                       mode = 'a', 
#                       index = False, 
#                       header = False
#                      )

# %%
wayback_devy_ranks['playerhref'] = wayback_devy_ranks['playerhref'].str.extract(r'https://keeptradecut.com/web/20210302174949/(.+)')

# %%
wayback_devy_ranks.head(50)
# Out:
#     rank                player  \
# 0      1       Trevor Lawrence
# 1      2         Justin Fields
# 2      3         Ja'Marr Chase
# 3      4          Najee Harris
# 4      5           Zach Wilson
# 5      6        Travis Etienne
# 6      7            Kyle Pitts
# 7      8            Trey Lance
# 8      9         DeVonta Smith
# 9     10           Breece Hall
# 10    11        Rashod Bateman
# 11    12      Javonte Williams
# 12    13            Sam Howell
# 13    14         Rondale Moore
# 14    15         Jaylen Waddle
# 15    16        Bijan Robinson
# 16    17             Mac Jones
# 17    18        George Pickens
# 18    19  Terrace Marshall Jr.
# 19    20       D.J. Uiagalelei
# 20    21        Isaiah Spiller
# 21    22        Garrett Wilson
# 22    23      Kenneth Gainwell
# 23    24       Spencer Rattler
# 24    25           Chris Olave
# 25    26         Tylan Wallace
# 26    27            David Bell
# 27    28     Amon-Ra St. Brown
# 28    29           Tank Bigsby
# 29    30          Elijah Moore
# 30    31        Pat Freiermuth
# 31    32           Dyami Brown
# 32    33          Kedon Slovis
# 33    34           Trey Sermon
# 34    35         Chuba Hubbard
# 35    36           Bryce Young
# 36    37           Zamir White
# 37    38        Kadarius Toney
# 38    39      Jermar Jefferson
# 39    40       Tamorrion Terry
# 40    41         Brevin Jordan
# 41    42         Seth Williams
# 42    43        Kyren Williams
# 43    44          Arik Gilbert
# 44    45            Zach Evans
# 45    46          Jahmyr Gibbs
# 46    47       Jaret Patterson
# 47    48          Jerrion Ealy
# 48    49        Jayden Daniels
# 49    50         Michael Mayer
#
#                                            playerhref positionrank schoolabv  \
# 0   https://keeptradecut.com/devy-rankings/players...          QB1      CLEM
# 1   https://keeptradecut.com/devy-rankings/players...          QB2       OSU
# 2   https://keeptradecut.com/devy-rankings/players...          WR1       LSU
# 3   https://keeptradecut.com/devy-rankings/players...          RB1       ALA
# 4   https://keeptradecut.com/devy-rankings/players...          QB3       BYU
# 5   https://keeptradecut.com/devy-rankings/players...          RB2      CLEM
# 6   https://keeptradecut.com/devy-rankings/players...          TE1       FLA
# 7   https://keeptradecut.com/devy-rankings/players...          QB4      NDSU
# 8   https://keeptradecut.com/devy-rankings/players...          WR2       ALA
# 9   https://keeptradecut.com/devy-rankings/players...          RB3       ISU
# 10  https://keeptradecut.com/devy-rankings/players...          WR3      MINN
# 11  https://keeptradecut.com/devy-rankings/players...          RB4       UNC
# 12  https://keeptradecut.com/devy-rankings/players...          QB5       UNC
# 13  https://keeptradecut.com/devy-rankings/players...          WR4       PUR
# 14  https://keeptradecut.com/devy-rankings/players...          WR5       ALA
# 15  https://keeptradecut.com/devy-rankings/players...          RB5       TEX
# 16  https://keeptradecut.com/devy-rankings/players...          QB6       ALA
# 17  https://keeptradecut.com/devy-rankings/players...          WR6       UGA
# 18  https://keeptradecut.com/devy-rankings/players...          WR7       LSU
# 19  https://keeptradecut.com/devy-rankings/players...          QB7      CLEM
# 20  https://keeptradecut.com/devy-rankings/players...          RB6      TA&M
# 21  https://keeptradecut.com/devy-rankings/players...          WR8       OSU
# 22  https://keeptradecut.com/devy-rankings/players...          RB7       MEM
# 23  https://keeptradecut.com/devy-rankings/players...          QB8      OKLA
# 24  https://keeptradecut.com/devy-rankings/players...          WR9       OSU
# 25  https://keeptradecut.com/devy-rankings/players...         WR10      OKST
# 26  https://keeptradecut.com/devy-rankings/players...         WR11       PUR
# 27  https://keeptradecut.com/devy-rankings/players...         WR12       USC
# 28  https://keeptradecut.com/devy-rankings/players...          RB8       AUB
# 29  https://keeptradecut.com/devy-rankings/players...         WR13      MISS
# 30  https://keeptradecut.com/devy-rankings/players...          TE2       PSU
# 31  https://keeptradecut.com/devy-rankings/players...         WR14       UNC
# 32  https://keeptradecut.com/devy-rankings/players...          QB9       USC
# 33  https://keeptradecut.com/devy-rankings/players...          RB9       OSU
# 34  https://keeptradecut.com/devy-rankings/players...         RB10      OKST
# 35  https://keeptradecut.com/devy-rankings/players...         QB10       ALA
# 36  https://keeptradecut.com/devy-rankings/players...         RB11       UGA
# 37  https://keeptradecut.com/devy-rankings/players...         WR15       FLA
# 38  https://keeptradecut.com/devy-rankings/players...         RB12      ORST
# 39  https://keeptradecut.com/devy-rankings/players...         WR16       FSU
# 40  https://keeptradecut.com/devy-rankings/players...          TE3     MIAMI
# 41  https://keeptradecut.com/devy-rankings/players...         WR17       AUB
# 42  https://keeptradecut.com/devy-rankings/players...         RB13        ND
# 43  https://keeptradecut.com/devy-rankings/players...          TE4       LSU
# 44  https://keeptradecut.com/devy-rankings/players...         RB14       TCU
# 45  https://keeptradecut.com/devy-rankings/players...         RB15        GT
# 46  https://keeptradecut.com/devy-rankings/players...         RB16      BUFF
# 47  https://keeptradecut.com/devy-rankings/players...         RB17      MISS
# 48  https://keeptradecut.com/devy-rankings/players...         QB11       ASU
# 49  https://keeptradecut.com/devy-rankings/players...          TE5        ND
#
#    overalltier  value       date
# 0       Tier 1   9975 2021-03-02
# 1       Tier 2   9530 2021-03-02
# 2       Tier 2   9425 2021-03-02
# 3       Tier 2   9228 2021-03-02
# 4       Tier 3   8891 2021-03-02
# 5       Tier 3   8890 2021-03-02
# 6       Tier 3   8841 2021-03-02
# 7       Tier 3   8712 2021-03-02
# 8       Tier 3   8597 2021-03-02
# 9       Tier 3   8494 2021-03-02
# 10      Tier 3   8481 2021-03-02
# 11      Tier 3   8449 2021-03-02
# 12      Tier 3   8420 2021-03-02
# 13      Tier 3   8362 2021-03-02
# 14      Tier 3   8352 2021-03-02
# 15      Tier 4   8030 2021-03-02
# 16      Tier 5   7828 2021-03-02
# 17      Tier 5   7768 2021-03-02
# 18      Tier 5   7641 2021-03-02
# 19      Tier 5   7529 2021-03-02
# 20      Tier 5   7420 2021-03-02
# 21      Tier 5   7377 2021-03-02
# 22      Tier 5   7340 2021-03-02
# 23      Tier 5   7316 2021-03-02
# 24      Tier 5   7287 2021-03-02
# 25      Tier 5   7261 2021-03-02
# 26      Tier 5   7249 2021-03-02
# 27      Tier 5   7241 2021-03-02
# 28      Tier 5   7224 2021-03-02
# 29      Tier 5   7196 2021-03-02
# 30      Tier 5   7114 2021-03-02
# 31      Tier 6   6891 2021-03-02
# 32      Tier 6   6876 2021-03-02
# 33      Tier 6   6787 2021-03-02
# 34      Tier 6   6776 2021-03-02
# 35      Tier 6   6699 2021-03-02
# 36      Tier 7   6551 2021-03-02
# 37      Tier 7   6473 2021-03-02
# 38      Tier 7   6322 2021-03-02
# 39      Tier 7   6199 2021-03-02
# 40      Tier 7   6133 2021-03-02
# 41      Tier 7   5996 2021-03-02
# 42      Tier 8   5830 2021-03-02
# 43      Tier 8   5751 2021-03-02
# 44      Tier 8   5739 2021-03-02
# 45      Tier 8   5646 2021-03-02
# 46      Tier 9   5470 2021-03-02
# 47     Tier 10   5284 2021-03-02
# 48     Tier 10   5277 2021-03-02
# 49     Tier 10   5257 2021-03-02

# %% [markdown]
# # Player page scrapes

# %%
player_attributes_list = []
player_value_history_list = []
dr_no_picks = wayback_devy_ranks.loc[~wayback_devy_ranks['player'].str.contains(r'\d{4}'), ['player', 'playerhref']]
for ind, row in dr_no_picks.iterrows():
    
    # save variables from dynasty_ranks
    player = row['player']
    href = row['playerhref']
    
    # open selenium and go to player's href page, click "All Time", and get page content for soup
    driver = webdriver.Firefox(executable_path=r'C:/Users/jrior/.ipython/drivers/geckodriver.exe')
    driver.get(f"{href}")
    try:
        alltime = driver.find_element(By.ID, "all-time")
        try:
            alltime.click()
        except:
            dontknow = driver.find_element(By.ID, "dont-know")
            dontknow.click()
            alltime.click()
        content = driver.page_source
        driver.close()

        # make the soup
        soup = BS(content)

        # get player measurables and append to list
        card = soup.find('div', {'class':'pd-measurables devy-measurables'})
        player_attributes = pd.DataFrame({
                                         'name':[f'{player}' for rowtitle in card.find_all('p', {'class':'row-title'})],
                                         'attribute':[rowtitle.text.strip('\n\t') for rowtitle in card.find_all('p', {'class':'row-title'})],
                                         'value':[rowvalue.text.strip('\n\t') for rowvalue in card.find_all('p', {'class':'row-value'})]
                                        })
        player_attributes_list.append(player_attributes)

        # get player value history and append to list
        valgraphsoup = soup.find("div", {"id":"pd-value-graph"})
        hovergroups = valgraphsoup.find_all("g", {"class":"hoverGroup"})
        player_value_history = pd.DataFrame({
                                             'name':[f'{player}' for hg in hovergroups],
                                             'date':[hg.find("text", {"class":"hoverDate"}).text for hg in hovergroups],
                                             'value':[hg.find("text", {"class":"graphVal hoverVal"}).text for hg in hovergroups]
                                            })
        player_value_history_list.append(player_value_history)
    except:
        print(f'error at {player}')
        driver.close()
        
    if (ind+1)%50 == 0:
        time.sleep(10)
    else:
        pass
# Out:
# <ipython-input-8-2f6f4976a9f4>:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=r'C:/Users/jrior/.ipython/drivers/geckodriver.exe')
# error at Joe Ngata
# error at Coleridge Stroud

# %%
attributes = pd.concat(player_attributes_list)
for col in ['attribute', 'value']:
    attributes[col] = attributes[col].str.strip()

# concatenate the historical values together
historical_values = pd.concat(player_value_history_list)

# convert date column to datetime
historical_values['date'] = pd.to_datetime(historical_values['date'])

# drop duplicate player-date pairs from historical values (meaning only keep the first entry of today's player-date pairs)
historical_values_clean = historical_values.drop_duplicates(subset = ['name', 'date'], keep = 'first')

# %% [markdown]
# # Read in dynasty player data and join with historical values to identify which players were drafted

# %%
historical_dynasty = pd.read_csv('../../data/ktc_historical_dynasty_values.csv')
historical_devy = pd.read_csv('../../data/ktc_historical_devy_values.csv')
devy_attributes = pd.read_csv('../../data/ktc_devy_player_attributes.csv')

# %%
player_already_in_devy_history = historical_devy['name'].unique()
player_became_rookie = historical_dynasty['name'].unique()

# %%
mask_out_rookie_zeros = (historical_values_clean['name'].isin(player_became_rookie)) & (historical_values_clean['date'] < '2021-03-17')
mask_out_duplicate_devy_histories = ~historical_values_clean['name'].isin(player_already_in_devy_history)

wayback_historical_values = historical_values_clean[mask_out_rookie_zeros & mask_out_duplicate_devy_histories]

# %%
wayback_attributes = attributes[~attributes['name'].isin(devy_attributes['name'].unique())]

# %% [markdown]
# # Append back

# %%
wayback_devy_ranks.to_csv(f'../../data/ktc_historical_devy_ranks.csv', mode = 'a', header = False, index = False)
wayback_attributes.to_csv(f'../../data/ktc_devy_player_attributes.csv', mode = 'a', header = False, index = False)
wayback_historical_values.to_csv(f'../../data/ktc_historical_devy_values.csv', mode = 'a', header = False, index = False)
